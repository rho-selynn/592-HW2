# %% [markdown]
# <a href="https://colab.research.google.com/github/rho-selynn/592-HW2/blob/main/Copy_of_592_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys
from google.colab import drive
# This mouunts your google drive to the current runtime
drive.mount('/content/mnt')
# We define a notebook path
nb_path = '/content/notebooks'
# We create a symbolic link from our drive's default "Colab Notebooks" folder to nb_path
os.symlink('/content/mnt/My Drive/Colab Notebooks/ME 592X/HW2', nb_path)
# Insert nb path
sys.path.insert(0, nb_path)
# Out:
# Mounted at /content/mnt

# %%
# !ls /content/mnt/MyDrive/Colab\ Notebooks/ME\ 592X/HW2/01
# Out:
# pcd0100cneg.txt  pcd0125cneg.txt  pcd0150cneg.txt  pcd0175cneg.txt
# pcd0100cpos.txt  pcd0125cpos.txt  pcd0150cpos.txt  pcd0175cpos.txt
# pcd0100d.tiff	 pcd0125d.tiff	  pcd0150d.tiff    pcd0175d.tiff
# pcd0100r.png	 pcd0125r.png	  pcd0150r.png	   pcd0175r.png
# pcd0100.txt	 pcd0125.txt	  pcd0150.txt	   pcd0175.txt
# pcd0101cneg.txt  pcd0126cneg.txt  pcd0151cneg.txt  pcd0176cneg.txt
# pcd0101cpos.txt  pcd0126cpos.txt  pcd0151cpos.txt  pcd0176cpos.txt
# pcd0101d.tiff	 pcd0126d.tiff	  pcd0151d.tiff    pcd0176d.tiff
# pcd0101r.png	 pcd0126r.png	  pcd0151r.png	   pcd0176r.png
# pcd0101.txt	 pcd0126.txt	  pcd0151.txt	   pcd0176.txt
# pcd0102cneg.txt  pcd0127cneg.txt  pcd0152cneg.txt  pcd0177cneg.txt
# pcd0102cpos.txt  pcd0127cpos.txt  pcd0152cpos.txt  pcd0177cpos.txt
# pcd0102d.tiff	 pcd0127d.tiff	  pcd0152d.tiff    pcd0177d.tiff
# pcd0102r.png	 pcd0127r.png	  pcd0152r.png	   pcd0177r.png
# pcd0102.txt	 pcd0127.txt	  pcd0152.txt	   pcd0177.txt
# ...

# %% [markdown]
# 1. Download the dataset and overlay the positive and negative grasping rectangles for each image on the raw image using the coordinates of the rectangles provided.
#
# The pos and neg txt files

# %%
# %matplotlib inline
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# Read Image
img = cv2.imread('/content/mnt/MyDrive/Colab Notebooks/ME 592X/HW2/01/pcd0100r.png',1)
# Display Image
cv2_imshow(img)
# Print error message if image is null
if img is None:
    print('Could not read image')
# make a copy of the original image
imageRectangle = img.copy()
# define the starting and end points of the rectangle
# using points from 'pcd0100cpos.txt'
start_point =(253,round(319.7)) # the rectangle function only takes int values
end_point =(309, 324)
# draw the rectangle
cv2.rectangle(imageRectangle, start_point, end_point, (0, 0, 255), thickness= 1, lineType=cv2.LINE_8) 
# display the output
cv2_imshow(imageRectangle)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F905BF2CF50>
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F905BF2CE10>
